# %%
import matplotlib.pyplot as plt
import numpy as np

# %matplotlib inline

# %%
points = np.array([
    [2.16, 2.07],
    [1.74, 1.37],
    [1.60, 1.05],
    [2.32, 1.19],
    [1.04, 0.71],
    [0.50, 0.59],
    [0.35, 0.32],
    [0.49, 0.32],
    [0.50, 0.21],
    [0.71, 0.28],
    [0.64, 0.49],
    [1.06, 0.37],
    [0.91, 0.45],
    [1.59, 0.68],
    [2.30, 0.35],
    [2.54, 0.68],
    [2.17, 0.86],
    [1.84, 0.45],
    [2.03, 0.48],
    [2.07, 0.49],
    [2.68, 0.52],
    [3.05, 0.76],
    [3.13, 1.03],
    [2.51, 1.02],
    [3.48, 0.57],
    [3.98, 0.99],
    [4.67, 1.07],
    [4.78, 1.10]
])

# %%
points = 12 * points/np.array([[5.16, 5.17]])

# %%
x_err = np.array([
    1.2, 0.44, 0.45, 0.76, 0.50, 0.11, 0.17, 0.17, 0.17, 0.34,
    0.59, 0.45, 0.29, 0.73,1.92, 1.53, 0.59, 0.69, 0.92, 0.91, 
    0.85, 1.73, 1.91, 0.68, 0.73, 0.73, 1.12, 1.64
]) 
y_err = np.array([
    1.26, 0.41, 0.42, 0.34, 0.22, 0.29, 0.06, 0.33, 0.12, 0.03,
    0.07, 0.18, 0.38, 0.14, 0.08, 0.45, 0.24, 0.11, 0.29, 0.22, 
    0.07, 0.73, 0.29, 0.31, 0.16, 0.57, 0.57, 0.17
])

# %%
fig, ax = plt.subplots(1, 1, figsize=(10, 10))

ax.errorbar(
    points[:, 0], points[:, 1],
    xerr=x_err, yerr=y_err,
    fmt='o', markersize=20,
    color='k', elinewidth=3)

ax.set_xlim([0, 12])
ax.set_ylim([0, 12])
ax.plot(ax.get_xlim(), ax.get_xlim(), color='gray', linewidth=3, zorder=-1)

ax.tick_params(labelsize=30)
ax.set_xlabel(r'\textbf{Total Variability (mV)}', fontsize=32, labelpad=10)
ax.set_ylabel(r'\textbf{Best Estimate for}' '\n' r'\textbf{Private Variability (mV)}', fontsize=32, labelpad=10)
ax.set_aspect('equal')

plt.tight_layout()
# plt.savefig('fig1b.pdf')
